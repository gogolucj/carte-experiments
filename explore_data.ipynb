# %% [markdown]
# # 데이터 탐색
#
# 영화 데이터와 카탈로그를 탐색합니다.
# - 특정 영화 검색
# - 카탈로그 테이블 확인
# - 원본 데이터 컬럼 확인

# %%
import sys
sys.path.insert(0, "/Users/jisoo/projects/thesis/carte_test")

import pandas as pd
import json
from pathlib import Path
from IPython.display import display, HTML

from config import RAW, PROCESSED

# Pandas 출력 설정
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 100)
pd.set_option('display.width', None)
pd.set_option('display.max_rows', 100)

print("Ready!")
# Out:
# Ready!

# %% [markdown]
# ---
# ## 1. 원본 데이터 컬럼 확인

# %%
# MovieLens 원본 데이터
print("=" * 60)
print("MovieLens 원본 데이터")
print("=" * 60)

# movies.csv
if RAW.MOVIES_CSV.exists():
    df_movies_raw = pd.read_csv(RAW.MOVIES_CSV, nrows=5)
    print(f"\n[movies.csv]")
    print(f"컬럼: {list(df_movies_raw.columns)}")
    display(df_movies_raw)

# links.csv
if RAW.LINKS_CSV.exists():
    df_links_raw = pd.read_csv(RAW.LINKS_CSV, nrows=5)
    print(f"\n[links.csv]")
    print(f"컬럼: {list(df_links_raw.columns)}")
    display(df_links_raw)

# ratings.csv
if RAW.RATINGS_CSV.exists():
    df_ratings_raw = pd.read_csv(RAW.RATINGS_CSV, nrows=5)
    print(f"\n[ratings.csv]")
    print(f"컬럼: {list(df_ratings_raw.columns)}")
    display(df_ratings_raw)

# %%
# TMDB 원본 데이터 (JSONL)
print("=" * 60)
print("TMDB 원본 데이터 (JSONL)")
print("=" * 60)

if RAW.TMDB_MOVIES_JSONL.exists():
    # 첫 번째 레코드만 읽어서 구조 확인
    with open(RAW.TMDB_MOVIES_JSONL, 'r') as f:
        first_line = f.readline()
        sample = json.loads(first_line)
    
    print(f"\n[tmdb_movies.jsonl] 최상위 키:")
    for key in sample.keys():
        val = sample[key]
        val_type = type(val).__name__
        if isinstance(val, str) and len(val) > 50:
            val = val[:50] + "..."
        elif isinstance(val, list) and len(val) > 3:
            val = val[:3] + ["..."]
        print(f"  - {key} ({val_type}): {val}")
else:
    print("TMDB JSONL 파일이 없습니다.")

# %%
# TMDB 샘플 레코드 전체 출력
if RAW.TMDB_MOVIES_JSONL.exists():
    print("[TMDB 샘플 레코드 전체]")
    print(json.dumps(sample, indent=2, ensure_ascii=False)[:3000])

# %% [markdown]
# ---
# ## 2. 처리된 데이터 컬럼 확인

# %%
# Movie Catalog (Processed)
print("=" * 60)
print("Movie Catalog (Processed)")
print("=" * 60)

df_catalog = pd.read_parquet(PROCESSED.MOVIE_CATALOG_PARQUET)
print(f"\n총 영화 수: {len(df_catalog):,}")
print(f"\n컬럼 ({len(df_catalog.columns)}개):")
for col in df_catalog.columns:
    dtype = df_catalog[col].dtype
    non_null = df_catalog[col].notna().sum()
    pct = non_null / len(df_catalog) * 100
    print(f"  - {col:30s} ({dtype}) - {non_null:,} ({pct:.1f}%)")
# Out:
# ============================================================
# Movie Catalog (Processed)
# ============================================================
#
# 총 영화 수: 86,272
#
# 컬럼 (20개):
#   - movieId                        (int64) - 86,272 (100.0%)
#   - tmdbId                         (int64) - 86,272 (100.0%)
#   - release_year                   (Int64) - 86,237 (100.0%)
#   - original_title                 (object) - 86,272 (100.0%)
#   - tagline                        (object) - 41,949 (48.6%)
#   - overview                       (object) - 85,991 (99.7%)
#   - produced_by_company_1          (object) - 75,547 (87.6%)
#   - produced_by_company_2          (object) - 42,891 (49.7%)
#   - produced_in_country_1          (object) - 81,610 (94.6%)
#   - produced_in_country_2          (object) - 15,524 (18.0%)
#   - spoken_language_1              (object) - 83,147 (96.4%)
#   - spoken_language_2              (object) - 15,329 (17.8%)
#   - actor_1                        (object) - 83,077 (96.3%)
#   - actor_2                        (object) - 80,250 (93.0%)
#   - actor_3                        (object) - 78,568 (91.1%)
#   - director_1                     (object) - 85,744 (99.4%)
#   - writer_1                       (object) - 75,990 (88.1%)
#   - genre_1                        (object) - 85,476 (99.1%)
#   - genre_2                        (object) - 56,493 (65.5%)
#   - genre_3                        (object) - 26,605 (30.8%)

# %%
# 카탈로그 샘플 확인
print("\n[카탈로그 샘플 (처음 5개)]")
display(df_catalog.head())
# Out:
# [카탈로그 샘플 (처음 5개)]
#    movieId  tmdbId  release_year      original_title  \
# 0     2858      14          1999     American Beauty
# 1      923      15          1941        Citizen Kane
# 2     1266      33          1992          Unforgiven
# 3     3910      16          2000  Dancer in the Dark
# 4    43589      17          2005            The Dark
#
#                                                                     tagline  \
# 0                                                           ... look closer
# 1                        Some called him a hero...others called him a heel.
# 2  Some legends will never be forgotten. Some wrongs can never be forgiven.
# 3                       In a world of shadows, she found the light of life.
# 4                                    One of the living for one of the dead.
#
#                                                                                               overview  \
# 0  Lester Burnham, a depressed suburban father in a mid-life crisis, decides to turn his hectic lif...
# 1  Newspaper magnate Charles Foster Kane is taken from his mother as a boy and made the ward of a r...
# 2  William Munny is a retired, once-ruthless killer turned gentle widower and hog farmer. To help s...
# 3  Selma, a Czech immigrant on the verge of blindness, struggles to make ends meet for herself and ...
# 4  In an attempt to pull her family together, Adèlle travels with her young daughter Sarah to Wales...
#
#      produced_by_company_1 produced_by_company_2     produced_in_country_1  \
# 0      DreamWorks Pictures   Jinks/Cohen Company  United States of America
# 1      Mercury Productions    RKO Radio Pictures  United States of America
# 2    Warner Bros. Pictures   Malpaso Productions  United States of America
# 3  Zentropa Entertainments                    DR                   Denmark
# 4          Constantin Film       Impact Pictures                   Germany
#
#   produced_in_country_2 spoken_language_1 spoken_language_2         actor_1  \
# 0                  None           English              None    Kevin Spacey
# 1                  None           English              None    Orson Welles
# 2                  None           English              None  Clint Eastwood
# 3               Finland           English              None           Björk
# 4        United Kingdom             Welsh           English     Maria Bello
#
#              actor_2            actor_3      director_1            writer_1  \
# 0     Annette Bening        Thora Birch      Sam Mendes           Alan Ball
# 1      Joseph Cotten  Dorothy Comingore    Orson Welles        Orson Welles
# 2       Gene Hackman     Morgan Freeman  Clint Eastwood  David Webb Peoples
# 3  Catherine Deneuve        David Morse  Lars von Trier      Lars von Trier
# 4          Sean Bean      Abigail Stone    John Fawcett  Stephen Massicotte
#
#    genre_1   genre_2  genre_3
# 0    Drama      None     None
# 1  Mystery     Drama     None
# 2  Western      None     None
# 3    Drama     Crime     None
# 4   Horror  Thriller  Mystery

# %%
# Embeddings
print("=" * 60)
print("Movie Embeddings")
print("=" * 60)

if PROCESSED.MOVIE_EMBEDDINGS_PARQUET.exists():
    df_emb = pd.read_parquet(PROCESSED.MOVIE_EMBEDDINGS_PARQUET)
    print(f"총 영화 수: {len(df_emb):,}")
    print(f"컬럼: {list(df_emb.columns)}")
    print(f"임베딩 차원: {len(df_emb['embedding'].iloc[0])}")
else:
    print("임베딩 파일이 없습니다.")
# Out:
# ============================================================
# Movie Embeddings
# ============================================================
# 총 영화 수: 86,272
# 컬럼: ['movieId', 'embedding']
# 임베딩 차원: 300

# %%
# Filtered Ratings
print("=" * 60)
print("Filtered Ratings")
print("=" * 60)

if PROCESSED.RATINGS_PARQUET.exists():
    df_ratings = pd.read_parquet(PROCESSED.RATINGS_PARQUET)
    print(f"총 평점 수: {len(df_ratings):,}")
    print(f"유저 수: {df_ratings['userId'].nunique():,}")
    print(f"영화 수: {df_ratings['movieId'].nunique():,}")
    print(f"컬럼: {list(df_ratings.columns)}")
    display(df_ratings.head())
else:
    print("평점 파일이 없습니다.")
# Out:
# ============================================================
# Filtered Ratings
# ============================================================
# 총 평점 수: 13,717,662
# 유저 수: 200,948
# 영화 수: 54,520
# 컬럼: ['userId', 'movieId', 'rating', 'timestamp']
#    userId  movieId  rating   timestamp
# 0       3     3248     4.0  1084486164
# 1       3     1957     5.0  1084486061
# 2       3      534     4.0  1084486058
# 3       3     2150     4.0  1084486055
# 4       3       26     4.0  1084486051

# %% [markdown]
# ---
# ## 3. 영화 검색

# %%
def search_movie(query: str, max_results: int = 20):
    """
    영화 제목으로 검색합니다.
    
    Args:
        query: 검색어 (부분 일치)
        max_results: 최대 결과 수
    """
    title_col = 'original_title' if 'original_title' in df_catalog.columns else 'title'
    
    mask = df_catalog[title_col].str.contains(query, case=False, na=False)
    results = df_catalog[mask].head(max_results)
    
    print(f"'{query}' 검색 결과: {mask.sum()}개 중 {len(results)}개 표시")
    print("=" * 80)
    
    if len(results) == 0:
        print("검색 결과가 없습니다.")
        return None
    
    # 간단한 목록 출력
    display_cols = [title_col, 'release_year', 'genre_1', 'director_1']
    display_cols = [c for c in display_cols if c in results.columns]
    display(results[display_cols])
    
    return results

# %%
# 검색 예시
search_movie("The Lord of the Rings")
# Out:
# 'The Lord of the Rings' 검색 결과: 6개 중 6개 표시
# ================================================================================
#                                                                  original_title  \
# 86                            The Lord of the Rings: The Fellowship of the Ring
# 87                                        The Lord of the Rings: The Two Towers
# 88                                The Lord of the Rings: The Return of the King
# 89                                                        The Lord of the Rings
# 69829            Passage to Middle-Earth: The Making of 'The Lord of the Rings'
# 79228  J.R.R. Tolkien and the Birth of "The Lord of the Rings" and "The Hobbit"
#
#        release_year      genre_1     director_1
# 86             2001    Adventure  Peter Jackson
# 87             2002    Adventure  Peter Jackson
# 88             2003    Adventure  Peter Jackson
# 89             1978    Adventure   Ralph Bakshi
# 69829          2001  Documentary           None
# 79228          2004  Documentary           None
#        movieId  tmdbId  release_year  \
# 86        4993     120          2001
# 87        5952     121          2002
# 88        7153     122          2003
# 89        2116     123          1978
# 69829   231829  453779          2001
# 79228   267392  651342          2004
#
#                                                                  original_title  \
# 86                            The Lord of the Rings: The Fellowship of the Ring
# 87                                        The Lord of the Rings: The Two Towers
# 88                                The Lord of the Rings: The Return of the King
# 89                                                        The Lord of the Rings
# 69829            Passage to Middle-Earth: The Making of 'The Lord of the Rings'
# 79228  J.R.R. Tolkien and the Birth of "The Lord of the Rings" and "The Hobbit"
#
#                                                                                                    tagline  \
# 86                                                                              One ring to rule them all.
# 87                                                                                  The journey continues.
# 88       There can be no triumph without loss. No victory without suffering. No freedom without sacrifice.
# 89                                                                       Fantasy...beyond your imagination
# 69829                                                                                                 None
# 79228  This program will give you a real insight into the man behind the legends of “THE LORD OF THE RI...
#
#                                                                                                   overview  \
# 86     Young hobbit Frodo Baggins, after inheriting a mysterious ring from his uncle Bilbo, must leave ...
# 87     Frodo Baggins and the other members of the Fellowship continue on their sacred quest to destroy ...
# 88     As armies mass for a final battle that will decide the fate of the world--and powerful, ancient ...
# 89     The Fellowship of the Ring embark on a journey to destroy the One Ring and end Sauron's reign ov...
# 69829                                  The making of Peter Jackson's adaptation of Tolkien's classic work.
# 79228  In a house in Oxford lived a remarkable man called J.R.R. Tolkien who told stories that thrilled...
#
#       produced_by_company_1 produced_by_company_2     produced_in_country_1  \
# 86          New Line Cinema         WingNut Films               New Zealand
# 87          New Line Cinema         WingNut Films               New Zealand
# 88          New Line Cinema         WingNut Films               New Zealand
# 89            Fantasy Films    Bakshi Productions            United Kingdom
# 69829               Highway   New Line Television  United States of America
# 79228                  None                  None                      None
#
#           produced_in_country_2 spoken_language_1 spoken_language_2  \
# 86     United States of America           English              None
# 87     United States of America           English              None
# 88     United States of America           English              None
# 89     United States of America           English              None
# 69829                      None           English              None
# 79228                      None           English              None
#
#                  actor_1         actor_2          actor_3     director_1  \
# 86           Elijah Wood    Ian McKellen  Viggo Mortensen  Peter Jackson
# 87           Elijah Wood    Ian McKellen  Viggo Mortensen  Peter Jackson
# 88           Elijah Wood    Ian McKellen  Viggo Mortensen  Peter Jackson
# 89     Christopher Guard  William Squire  Michael Scholes   Ralph Bakshi
# 69829        Elijah Wood   Peter Jackson     Ian McKellen           None
# 79228               None            None             None           None
#
#               writer_1      genre_1    genre_2  genre_3
# 86     Philippa Boyens    Adventure    Fantasy   Action
# 87          Fran Walsh    Adventure    Fantasy   Action
# 88       Peter Jackson    Adventure    Fantasy   Action
# 89     Peter S. Beagle    Adventure  Animation  Fantasy
# 69829             None  Documentary   TV Movie     None
# 79228             None  Documentary       None     None

# %%
search_movie("Hobbit")
# Out:
# 'Hobbit' 검색 결과: 5개 중 5개 표시
# ================================================================================
#                                                                  original_title  \
# 22713                                         The Hobbit: An Unexpected Journey
# 25812                                       The Hobbit: The Desolation of Smaug
# 37027                                             J. R. R. Tolkien's The Hobbit
# 41063                                 The Hobbit: The Battle of the Five Armies
# 79228  J.R.R. Tolkien and the Birth of "The Lord of the Rings" and "The Hobbit"
#
#        release_year      genre_1     director_1
# 22713          2012    Adventure  Peter Jackson
# 25812          2013      Fantasy  Peter Jackson
# 37027          1967    Animation    Gene Deitch
# 41063          2014       Action  Peter Jackson
# 79228          2004  Documentary           None
#        movieId  tmdbId  release_year  \
# 22713    98809   49051          2012
# 25812   106489   57158          2013
# 37027   249698   99457          1967
# 41063   118696  122917          2014
# 79228   267392  651342          2004
#
#                                                                  original_title  \
# 22713                                         The Hobbit: An Unexpected Journey
# 25812                                       The Hobbit: The Desolation of Smaug
# 37027                                             J. R. R. Tolkien's The Hobbit
# 41063                                 The Hobbit: The Battle of the Five Armies
# 79228  J.R.R. Tolkien and the Birth of "The Lord of the Rings" and "The Hobbit"
#
#                                                                                                    tagline  \
# 22713                                              From the smallest beginnings come the greatest legends.
# 25812                             Beyond darkness... beyond desolation... lies the greatest danger of all.
# 37027                                                                                                 None
# 41063                                                                 Will you follow me... one last time?
# 79228  This program will give you a real insight into the man behind the legends of “THE LORD OF THE RI...
#
#                                                                                                   overview  \
# 22713  Bilbo Baggins, a hobbit enjoying his quiet life, is swept into an epic quest by Gandalf the Grey...
# 25812  The Dwarves, Bilbo and Gandalf have successfully escaped the Misty Mountains, and Bilbo has gain...
# 37027  The very first movie adaptation of J.R.R Tolkien's The Hobbit. Made in just 30 days so that the ...
# 41063  Following Smaug's attack on Laketown, Bilbo and the dwarves try to defend Erebor's mountain of t...
# 79228  In a house in Oxford lived a remarkable man called J.R.R. Tolkien who told stories that thrilled...
#
#       produced_by_company_1 produced_by_company_2 produced_in_country_1  \
# 22713       New Line Cinema   Metro-Goldwyn-Mayer           New Zealand
# 25812       New Line Cinema   Metro-Goldwyn-Mayer           New Zealand
# 37027       Rembrandt Films                  None        Czechoslovakia
# 41063       New Line Cinema   Metro-Goldwyn-Mayer           New Zealand
# 79228                  None                  None                  None
#
#           produced_in_country_2 spoken_language_1 spoken_language_2  \
# 22713  United States of America           English              None
# 25812  United States of America           English              None
# 37027  United States of America           English              None
# 41063  United States of America           English              None
# 79228                      None           English              None
#
#               actor_1         actor_2           actor_3     director_1  \
# 22713  Martin Freeman    Ian McKellen  Richard Armitage  Peter Jackson
# 25812    Ian McKellen  Martin Freeman  Richard Armitage  Peter Jackson
# 37027    Herbert Lass            None              None    Gene Deitch
# 41063    Ian McKellen  Martin Freeman  Richard Armitage  Peter Jackson
# 79228            None            None              None           None
#
#               writer_1      genre_1    genre_2    genre_3
# 22713       Fran Walsh    Adventure    Fantasy     Action
# 25812  Philippa Boyens      Fantasy  Adventure     Action
# 37027      Gene Deitch    Animation    Fantasy  Adventure
# 41063    Peter Jackson       Action  Adventure    Fantasy
# 79228             None  Documentary       None       None

# %%
search_movie("Godfather")
# Out:
# 'Godfather' 검색 결과: 15개 중 15개 표시
# ================================================================================
#                                       original_title  release_year  \
# 187                                    The Godfather          1972
# 189                            The Godfather Part II          1974
# 191                           The Godfather Part III          1990
# 13526                                   3 Godfathers          1948
# 25491            The Godfather Family: A Look Inside          1990
# 26353  Herschell Gordon Lewis: The Godfather of Gore          2010
# 31683                                Disco Godfather          1979
# 32664                            The Black Godfather          1974
# 44807                               Three Godfathers          1936
# 50663       The Rockford Files: Godfather Knows Best          1996
# 58486                           The Godfather Legacy          2012
# 69840      The Medici: Godfathers of the Renaissance          2004
# 74154           Fred: The Godfather of British Crime          2018
# 77366                                  Our Godfather          2019
# 77659                            The Black Godfather          2019
#
#            genre_1            director_1
# 187          Drama  Francis Ford Coppola
# 189          Drama  Francis Ford Coppola
# 191          Crime  Francis Ford Coppola
# 13526      Western             John Ford
# 25491  Documentary           Jeff Werner
# 26353  Documentary     Frank Henenlotter
# 31683       Action     J. Robert Wagoner
# 32664       Action            John Evans
# 44807       Action   Richard Boleslawski
# 50663        Crime          Tony Wharmby
# 58486  Documentary           Kevin Burns
# 69840  Documentary          Justin Hardy
# 74154  Documentary       Paul van Carter
# 77366  Documentary          Andrew Meier
# 77659  Documentary       Reginald Hudlin
#        movieId  tmdbId  release_year  \
# 187        858     238          1972
# 189       1221     240          1974
# 191       2023     242          1990
# 13526    25934   29244          1948
# 25491   188173   56205          1990
# 26353   176537   58862          2010
# 31683   106704   77403          1979
# 32664   123880   80755          1974
# 44807   124791  149955          1936
# 50663   217963  208391          1996
# 58486   188155  294636          2012
# 69840   172115  454229          2004
# 74154   198927  526803          2018
# 77366   206423  598065          2019
# 77659   203302  606215          2019
#
#                                       original_title  \
# 187                                    The Godfather
# 189                            The Godfather Part II
# 191                           The Godfather Part III
# 13526                                   3 Godfathers
# 25491            The Godfather Family: A Look Inside
# 26353  Herschell Gordon Lewis: The Godfather of Gore
# 31683                                Disco Godfather
# 32664                            The Black Godfather
# 44807                               Three Godfathers
# 50663       The Rockford Files: Godfather Knows Best
# 58486                           The Godfather Legacy
# 69840      The Medici: Godfathers of the Renaissance
# 74154           Fred: The Godfather of British Crime
# 77366                                  Our Godfather
# 77659                            The Black Godfather
#
#                                                                                     tagline  \
# 187                                                              An offer you can't refuse.
# 189                                               The rise and fall of the Corleone empire.
# 191                                            All the power on earth can't change destiny.
# 13526                                                  John Ford's Legend of the Southwest!
# 25491                                                                                  None
# 26353                                                                                  None
# 31683                                                            Touch him and you're dust!
# 32664                                                    There's a new godfather in town...
# 44807  On the brink of hell...a baby's smile came into the darkened souls of three bad men!
# 50663                                                                                  None
# 58486                                           I'm gonna make him an offer he can't refuse
# 69840                                                                                  None
# 74154                                                                                  None
# 77366                                                      The man the Mafia could not kill
# 77659                                                                Music. Power. Respect.
#
#                                                                                                   overview  \
# 187    Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime fa...
# 189    In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily an...
# 191    In the midst of trying to legitimize his business dealings in 1979 New York and Italy, aging maf...
# 13526  Three outlaws on the run discover a dying woman and her baby. They swear to bring the infant to ...
# 25491  A documentary on the making of the three Godfather films, with interviews and recollections from...
# 26353  Take an outrageous ride through this wild world of exploitation films with this thoroughly enter...
# 31683  Retired cop and celebrity DJ Tucker Williams (aka The Disco Godfather) takes to the streets as a...
# 32664  The heroes in The Black Godfather are members of an African-American criminal organization. Like...
# 44807  In a town called New Jerusalem, three bandits hold up a bank. After a gun battle with the townsp...
# 50663  Jim Rockford tries to help his godson, son of Denis Becker, rise out of poverty and homelessness...
# 58486  THE GODFATHER LEGACY goes deep inside Francis Ford Coppola's epic saga about the Corleone crime ...
# 69840  From a small Italian community in 15th-century Florence, the Medici family would rise to rule Eu...
# 74154  This is an examination into the psyche of former London gangster Freddie Foreman: 85 years old, ...
# 77366  The story of how Sicilian Mafia boss Tommaso Buscetta (1928-2000), the Godfather of Two Worlds, ...
# 77659  Follows the life of Clarence Avant, the ultimate, uncensored mentor and behind-the-scenes rainma...
#
#                produced_by_company_1     produced_by_company_2  \
# 187               Paramount Pictures        Alfran Productions
# 189               Paramount Pictures       The Coppola Company
# 191               Paramount Pictures         American Zoetrope
# 13526                Argosy Pictures       Metro-Goldwyn-Mayer
# 25491             Paramount Pictures         American Zoetrope
# 26353    Something Weird Video (SWV)                      None
# 31683       Generation International                      None
# 32664            Cougnar Productions                      None
# 44807            Metro-Goldwyn-Mayer                      None
# 50663                           None                      None
# 58486                        History  Prometheus Entertainment
# 69840  Devillier Donegan Enterprises           Lion Television
# 74154                 Salon Pictures          Premiere Picture
# 77366              Black Earth Films            Phenomen Films
# 77659             Boardwalk Pictures                  MakeMake
#
#           produced_in_country_1     produced_in_country_2 spoken_language_1  \
# 187    United States of America                      None           English
# 189    United States of America                      None           English
# 191    United States of America                      None           English
# 13526  United States of America                      None           Spanish
# 25491                      None                      None           English
# 26353  United States of America                      None           English
# 31683  United States of America                      None           English
# 32664  United States of America                      None           English
# 44807  United States of America                      None           English
# 50663                      None                      None           English
# 58486  United States of America                      None           English
# 69840            United Kingdom  United States of America           English
# 74154            United Kingdom                      None           English
# 77366            United Kingdom                      None           English
# 77659  United States of America                      None           English
#
#       spoken_language_2                 actor_1           actor_2  \
# 187             Italian           Marlon Brando         Al Pacino
# 189             Italian               Al Pacino     Robert Duvall
# 191             Italian               Al Pacino      Diane Keaton
# 13526           English              John Wayne  Pedro Armendáriz
# 25491           Italian    Francis Ford Coppola        Mario Puzo
# 26353              None  Herschell Gordon Lewis       John Waters
# 31683              None          Rudy Ray Moore       Carol Speed
# 32664              None               Rod Perry         Damu King
# 44807              None          Chester Morris       Lewis Stone
# 50663              None            James Garner   Stuart Margolin
# 58486              None              Peter Bart        James Caan
# 69840              None        Massimo Marinoni    Peter Guinness
# 74154              None                    None              None
# 77366           Italian            Nino D'Agata     Brandon Veliz
# 77659              None          Clarence Avant      Quincy Jones
#
#                     actor_3            director_1           writer_1  \
# 187              James Caan  Francis Ford Coppola         Mario Puzo
# 189            Diane Keaton  Francis Ford Coppola         Mario Puzo
# 191             Talia Shire  Francis Ford Coppola         Mario Puzo
# 13526      Harry Carey, Jr.             John Ford      Robert Nathan
# 25491            James Caan           Jeff Werner      David Gilbert
# 26353             Ray Sager     Frank Henenlotter               None
# 31683           Jimmy Lynch     J. Robert Wagoner  J. Robert Wagoner
# 32664          Don Chastain            John Evans         John Evans
# 44807        Walter Brennan   Richard Boleslawski   Ainsworth Morgan
# 50663     Maxwell Caulfield          Tony Wharmby               None
# 58486  Francis Ford Coppola           Kevin Burns        Kevin Burns
# 69840           Ian Bustard          Justin Hardy        Susan Horth
# 74154                  None       Paul van Carter               None
# 77366        Filip Kiritsis          Andrew Meier    Mark Franchetti
# 77659          Barack Obama       Reginald Hudlin               None
#
#            genre_1   genre_2   genre_3
# 187          Drama     Crime      None
# 189          Drama     Crime      None
# 191          Crime     Drama  Thriller
# 13526      Western      None      None
# 25491  Documentary  TV Movie      None
# 26353  Documentary    Horror      None
# 31683       Action    Comedy     Crime
# 32664       Action     Crime  Thriller
# 44807       Action     Drama   Western
# 50663        Crime   Mystery  TV Movie
# 58486  Documentary  TV Movie      None
# 69840  Documentary   History      None
# 74154  Documentary      None      None
# 77366  Documentary   History      None
# 77659  Documentary     Music      None

# %% [markdown]
# ---
# ## 4. 특정 영화 상세 정보

# %%
def show_movie_detail(query: str):
    """
    특정 영화의 전체 카탈로그 정보를 표시합니다.
    
    Args:
        query: 영화 제목 (부분 일치, 첫 번째 결과 사용)
    """
    title_col = 'original_title' if 'original_title' in df_catalog.columns else 'title'
    
    mask = df_catalog[title_col].str.contains(query, case=False, na=False)
    
    if mask.sum() == 0:
        print(f"'{query}'에 해당하는 영화를 찾을 수 없습니다.")
        return None
    
    movie = df_catalog[mask].iloc[0]
    
    print("=" * 80)
    print(f"{movie[title_col]} ({movie.get('release_year', 'N/A')})")
    print("=" * 80)
    
    # 모든 필드 출력
    for col in df_catalog.columns:
        val = movie[col]
        if pd.notna(val) and val != '':
            val_str = str(val)
            if len(val_str) > 100:
                val_str = val_str[:100] + "..."
            print(f"  {col:30s}: {val_str}")
    
    return movie

# %%
# 상세 정보 예시
show_movie_detail("Toy Story")
# Out:
# ================================================================================
# Toy Story (1995)
# ================================================================================
#   movieId                       : 1
#   tmdbId                        : 862
#   release_year                  : 1995
#   original_title                : Toy Story
#   tagline                       : Hang on for the comedy that goes to infinity and beyond!
#   overview                      : Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto ...
#   produced_by_company_1         : Pixar
#   produced_in_country_1         : United States of America
#   spoken_language_1             : English
#   actor_1                       : Tom Hanks
#   actor_2                       : Tim Allen
#   actor_3                       : Don Rickles
#   director_1                    : John Lasseter
#   writer_1                      : Joss Whedon
#   genre_1                       : Family
#   genre_2                       : Comedy
#   genre_3                       : Animation
# movieId                                                                                                                    1
# tmdbId                                                                                                                   862
# release_year                                                                                                            1995
# original_title                                                                                                     Toy Story
# tagline                                                             Hang on for the comedy that goes to infinity and beyond!
# overview                 Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear o...
# produced_by_company_1                                                                                                  Pixar
# produced_by_company_2                                                                                                   None
# produced_in_country_1                                                                               United States of America
# produced_in_country_2                                                                                                   None
# spoken_language_1                                                                                                    English
# spoken_language_2                                                                                                       None
# actor_1                                                                                                            Tom Hanks
# actor_2                                                                                                            Tim Allen
# actor_3                                                                                                          Don Rickles
# director_1                                                                                                     John Lasseter
# writer_1                                                                                                         Joss Whedon
# genre_1                                                                                                               Family
# genre_2                                                                                                               Comedy
# genre_3                                                                                                            Animation
# Name: 691, dtype: object

# %%
show_movie_detail("Inception")
# Out:
# ================================================================================
# Inception (2010)
# ================================================================================
#   movieId                       : 79132
#   tmdbId                        : 27205
#   release_year                  : 2010
#   original_title                : Inception
#   tagline                       : Your mind is the scene of the crime.
#   overview                      : Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his target...
#   produced_by_company_1         : Legendary Pictures
#   produced_by_company_2         : Syncopy
#   produced_in_country_1         : United Kingdom
#   produced_in_country_2         : United States of America
#   spoken_language_1             : English
#   spoken_language_2             : French
#   actor_1                       : Leonardo DiCaprio
#   actor_2                       : Joseph Gordon-Levitt
#   actor_3                       : Ken Watanabe
#   director_1                    : Christopher Nolan
#   writer_1                      : Christopher Nolan
#   genre_1                       : Action
#   genre_2                       : Science Fiction
#   genre_3                       : Adventure
# movieId                                                                                                                79132
# tmdbId                                                                                                                 27205
# release_year                                                                                                            2010
# original_title                                                                                                     Inception
# tagline                                                                                 Your mind is the scene of the crime.
# overview                 Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his ta...
# produced_by_company_1                                                                                     Legendary Pictures
# produced_by_company_2                                                                                                Syncopy
# produced_in_country_1                                                                                         United Kingdom
# produced_in_country_2                                                                               United States of America
# spoken_language_1                                                                                                    English
# spoken_language_2                                                                                                     French
# actor_1                                                                                                    Leonardo DiCaprio
# actor_2                                                                                                 Joseph Gordon-Levitt
# actor_3                                                                                                         Ken Watanabe
# director_1                                                                                                 Christopher Nolan
# writer_1                                                                                                   Christopher Nolan
# genre_1                                                                                                               Action
# genre_2                                                                                                      Science Fiction
# genre_3                                                                                                            Adventure
# Name: 12543, dtype: object

# %%
show_movie_detail("The Dark Knight")
# Out:
# ================================================================================
# The Dark Knight (2008)
# ================================================================================
#   movieId                       : 58559
#   tmdbId                        : 155
#   release_year                  : 2008
#   original_title                : The Dark Knight
#   tagline                       : Welcome to a world without rules.
#   overview                      : Batman raises the stakes in his war on crime. With the help of Lt. Jim Gordon and District Attorney ...
#   produced_by_company_1         : Warner Bros. Pictures
#   produced_by_company_2         : Legendary Pictures
#   produced_in_country_1         : United Kingdom
#   produced_in_country_2         : United States of America
#   spoken_language_1             : English
#   spoken_language_2             : Mandarin
#   actor_1                       : Christian Bale
#   actor_2                       : Heath Ledger
#   actor_3                       : Aaron Eckhart
#   director_1                    : Christopher Nolan
#   writer_1                      : Christopher Nolan
#   genre_1                       : Drama
#   genre_2                       : Action
#   genre_3                       : Crime
# movieId                                                                                                                58559
# tmdbId                                                                                                                   155
# release_year                                                                                                            2008
# original_title                                                                                               The Dark Knight
# tagline                                                                                    Welcome to a world without rules.
# overview                 Batman raises the stakes in his war on crime. With the help of Lt. Jim Gordon and District Attor...
# produced_by_company_1                                                                                  Warner Bros. Pictures
# produced_by_company_2                                                                                     Legendary Pictures
# produced_in_country_1                                                                                         United Kingdom
# produced_in_country_2                                                                               United States of America
# spoken_language_1                                                                                                    English
# spoken_language_2                                                                                                   Mandarin
# actor_1                                                                                                       Christian Bale
# actor_2                                                                                                         Heath Ledger
# actor_3                                                                                                        Aaron Eckhart
# director_1                                                                                                 Christopher Nolan
# writer_1                                                                                                   Christopher Nolan
# genre_1                                                                                                                Drama
# genre_2                                                                                                               Action
# genre_3                                                                                                                Crime
# Name: 52, dtype: object

# %% [markdown]
# ---
# ## 5. 카테고리별 분포 확인

# %%
# 장르 분포
print("[장르 분포 (genre_1)]")
print(df_catalog['genre_1'].value_counts().head(20))
# Out:
# [장르 분포 (genre_1)]
# genre_1
# Drama              22256
# Comedy             16611
# Documentary         9073
# Action              6326
# Horror              5755
# Animation           3555
# Thriller            3522
# Crime               3223
# Romance             2777
# Adventure           2301
# Science Fiction     1649
# Family              1468
# Music               1154
# Mystery             1144
# Western             1140
# Fantasy             1124
# TV Movie            1025
# War                  777
# History              596
# Name: count, dtype: int64

# %%
# 연도 분포
print("[연도 분포]")
year_counts = df_catalog['release_year'].value_counts().sort_index()
print(f"연도 범위: {year_counts.index.min()} ~ {year_counts.index.max()}")
print(f"\n최근 10년:")
print(year_counts.tail(10))
# Out:
# [연도 분포]
# 연도 범위: 1874 ~ 2025
#
# 최근 10년:
# release_year
# 2016    3134
# 2017    3256
# 2018    3181
# 2019    3114
# 2020    2497
# 2021    2362
# 2022    2118
# 2023    1040
# 2024      35
# 2025      13
# Name: count, dtype: Int64

# %%
# 제작 국가 분포
if 'produced_in_country_1' in df_catalog.columns:
    print("[제작 국가 분포]")
    print(df_catalog['produced_in_country_1'].value_counts().head(15))
# Out:
# [제작 국가 분포]
# produced_in_country_1
# United States of America    34722
# United Kingdom               6052
# France                       5529
# Canada                       3900
# Japan                        3035
# Italy                        2994
# Germany                      2731
# India                        2361
# Spain                        1443
# Australia                    1132
# Russia                       1080
# South Korea                  1031
# Hong Kong                    1016
# Soviet Union                 1003
# Belgium                       974
# Name: count, dtype: int64

# %%
# 다작 감독
if 'director_1' in df_catalog.columns:
    print("[다작 감독 TOP 20]")
    print(df_catalog['director_1'].value_counts().head(20))
# Out:
# [다작 감독 TOP 20]
# director_1
# Georges Méliès      118
# Chuck Jones         102
# Friz Freleng        100
# Tex Avery            86
# Michael Curtiz       77
# John Ford            70
# Richard Thorpe       64
# Werner Herzog        62
# Jean-Luc Godard      62
# Charlie Chaplin      62
# David DeCoteau       60
# Jack Hannah          58
# Gordon Douglas       56
# William Beaudine     56
# Alfred Hitchcock     56
# Raoul Walsh          56
# Henry Hathaway       55
# Lloyd Bacon          55
# Mervyn LeRoy         54
# D.W. Griffith        53
# Name: count, dtype: int64

# %%
# 다작 배우
if 'actor_1' in df_catalog.columns:
    print("[다작 배우 TOP 20]")
    print(df_catalog['actor_1'].value_counts().head(20))
# Out:
# [다작 배우 TOP 20]
# actor_1
# Mel Blanc           232
# Clarence Nash       116
# John Wayne          106
# Nicolas Cage         78
# Charlie Chaplin      76
# Georges Méliès       72
# Jackie Chan          66
# Akshay Kumar         65
# Pinto Colvig         61
# Robert De Niro       59
# Stan Laurel          58
# Burt Reynolds        57
# Isabelle Huppert     57
# Barbara Stanwyck     57
# Bing Crosby          56
# Michael Caine        56
# Alberto Sordi        56
# Gérard Depardieu     54
# Ajay Devgn           54
# Leo Gorcey           54
# Name: count, dtype: int64

# %% [markdown]
# ---
# ## 6. 직접 검색

# %%
# 원하는 영화 제목을 입력하세요
search_movie("Avengers")
# Out:
# 'Avengers' 검색 결과: 11개 중 11개 표시
# ================================================================================
#                                         original_title  release_year  \
# 3473                                      The Avengers          1998
# 6899                               Ultimate Avengers 2          2006
# 7028                 Next Avengers: Heroes of Tomorrow          2008
# 11084                                     The Avengers          2012
# 37097                          Avengers: Age of Ultron          2015
# 47852                                       Scavengers          2013
# 58944                                Avengers: Endgame          2019
# 58945                           Avengers: Infinity War          2018
# 60460                                   Avengers Grimm          2015
# 63877  LEGO Marvel Super Heroes: Avengers Reassembled!          2015
# 73884                        Avengers Grimm: Time Wars          2018
#
#                genre_1           director_1
# 3473            Action  Jeremiah S. Chechik
# 6899         Adventure        Will Meugniot
# 7028         Animation            Jay Oliva
# 11084  Science Fiction          Joss Whedon
# 37097           Action          Joss Whedon
# 47852  Science Fiction       Travis Zariwny
# 58944        Adventure        Anthony Russo
# 58945        Adventure            Joe Russo
# 60460           Action      Jeremy M. Inman
# 63877           Family        Rob Silvestri
# 73884           Action   Maximilian Elfeldt
#        movieId  tmdbId  release_year  \
# 3473      2153    9320          1998
# 6899    170297   14611          2006
# 7028    135979   14613          2008
# 11084    89745   24428          2012
# 37097   122892   99861          2015
# 47852   169616  179105          2013
# 58944   122914  299534          2019
# 58945   122912  299536          2018
# 60460   136257  323660          2015
# 63877   187221  368304          2015
# 73884   189217  521720          2018
#
#                                         original_title  \
# 3473                                      The Avengers
# 6899                               Ultimate Avengers 2
# 7028                 Next Avengers: Heroes of Tomorrow
# 11084                                     The Avengers
# 37097                          Avengers: Age of Ultron
# 47852                                       Scavengers
# 58944                                Avengers: Endgame
# 58945                           Avengers: Infinity War
# 60460                                   Avengers Grimm
# 63877  LEGO Marvel Super Heroes: Avengers Reassembled!
# 73884                        Avengers Grimm: Time Wars
#
#                                                                                                 tagline  \
# 3473                                                                         Saving the World in Style.
# 6899   To save humanity, the Earth's mightiest heroes must reunite for a rematch of heroic proportions.
# 7028                                      The children of heroes past are our only hope for the future!
# 11084                                                                           Some assembly required.
# 37097                                                                               A new age has come.
# 47852                                                                                 Survive the void.
# 58944                                                                                Avenge the fallen.
# 58945                                                                     Destiny arrives all the same.
# 60460                                                                A battle of legendary proportions.
# 63877                                                                                              None
# 73884                                                                        The original wonder women!
#
#                                                                                                   overview  \
# 3473   British Ministry agent John Steed, under direction from "Mother", investigates a diabolical plot...
# 6899   Mysterious Wakanda lies in the darkest heart of Africa, unknown to most of the world. An isolate...
# 7028   The children of the Avengers hone their powers and go head to head with the very enemy responsib...
# 11084  When an unexpected enemy emerges and threatens global safety and security, Nick Fury, director o...
# 37097  When Tony Stark tries to jumpstart a dormant peacekeeping program, things go awry and Earth’s Mi...
# 47852  A team of space scavengers discovers superior alien technology that threatens the balance of the...
# 58944  After the devastating events of Avengers: Infinity War, the universe is in ruins due to the effo...
# 58945  As the Avengers and their allies have continued to protect the world from threats too large for ...
# 60460  When Rumpelstiltskin destroys the Magic Mirror and escapes to the modern world, the four princes...
# 63877  The Avengers are forced to “party” with Ultron when he seeks to disassemble the team by taking c...
# 73884  When Rumpelstiltskin tries to take over Earth once and for all, The Avengers Grimm must track hi...
#
#              produced_by_company_1  produced_by_company_2  \
# 3473   Jerry Weintraub Productions  Warner Bros. Pictures
# 6899             MLG Productions 2              Lionsgate
# 7028             MLG Productions 5              Lionsgate
# 11084               Marvel Studios                   None
# 37097               Marvel Studios                   None
# 47852          California Pictures                   None
# 58944               Marvel Studios                   None
# 58945               Marvel Studios                   None
# 60460                   The Asylum                   None
# 63877              Arc Productions   Marvel Entertainment
# 73884                   The Asylum                   None
#
#           produced_in_country_1 produced_in_country_2 spoken_language_1  \
# 3473   United States of America                  None           English
# 6899   United States of America                  None           English
# 7028   United States of America                  None           English
# 11084  United States of America                  None           English
# 37097  United States of America                  None           English
# 47852  United States of America                  None           English
# 58944  United States of America                  None           English
# 58945  United States of America                  None           English
# 60460  United States of America                  None           English
# 63877  United States of America                  None           English
# 73884  United States of America                  None           English
#
#       spoken_language_2            actor_1           actor_2          actor_3  \
# 3473            Spanish      Ralph Fiennes       Uma Thurman     Sean Connery
# 6899               None       Justin Gross   Jeffrey D. Sams     Grey DeLisle
# 7028               None      Noah Crawford    Brenna O'Brien   Aidan Drummond
# 11084             Hindi  Robert Downey Jr.       Chris Evans     Mark Ruffalo
# 37097              None  Robert Downey Jr.   Chris Hemsworth     Mark Ruffalo
# 47852              None      John Lee Ames   Roark Critchlow     Brett Curtze
# 58944          Japanese  Robert Downey Jr.       Chris Evans     Mark Ruffalo
# 58945             Xhosa  Robert Downey Jr.       Chris Evans  Chris Hemsworth
# 60460              None    Casper Van Dien      Lou Ferrigno    Kimo Leopoldo
# 63877              None       Laura Bailey        Troy Baker       Eric Bauza
# 73884              None   Marah Fairclough  Lauren Parkinson      Eric Feltes
#
#                 director_1             writer_1          genre_1  \
# 3473   Jeremiah S. Chechik       Don MacPherson           Action
# 6899         Will Meugniot         Greg Johnson        Adventure
# 7028             Jay Oliva  Christopher L. Yost        Animation
# 11084          Joss Whedon          Joss Whedon  Science Fiction
# 37097          Joss Whedon          Joss Whedon           Action
# 47852       Travis Zariwny       Travis Zariwny  Science Fiction
# 58944        Anthony Russo      Stephen McFeely        Adventure
# 58945            Joe Russo      Stephen McFeely        Adventure
# 60460      Jeremy M. Inman      Jeremy M. Inman           Action
# 63877        Rob Silvestri       Mark Hoffmeier           Family
# 73884   Maximilian Elfeldt      Jeremy M. Inman           Action
#
#                genre_2          genre_3
# 3473         Adventure         Thriller
# 6899         Animation           Action
# 7028            Family           Action
# 11084           Action        Adventure
# 37097        Adventure  Science Fiction
# 47852           Action             None
# 58944  Science Fiction           Action
# 58945           Action  Science Fiction
# 60460          Fantasy             None
# 63877        Animation             None
# 73884        Adventure          Fantasy

# %%
# 상세 정보 확인
show_movie_detail("Avengers: Endgame")
# Out:
# ================================================================================
# Avengers: Endgame (2019)
# ================================================================================
#   movieId                       : 122914
#   tmdbId                        : 299534
#   release_year                  : 2019
#   original_title                : Avengers: Endgame
#   tagline                       : Avenge the fallen.
#   overview                      : After the devastating events of Avengers: Infinity War, the universe is in ruins due to the efforts ...
#   produced_by_company_1         : Marvel Studios
#   produced_in_country_1         : United States of America
#   spoken_language_1             : English
#   spoken_language_2             : Japanese
#   actor_1                       : Robert Downey Jr.
#   actor_2                       : Chris Evans
#   actor_3                       : Mark Ruffalo
#   director_1                    : Anthony Russo
#   writer_1                      : Stephen McFeely
#   genre_1                       : Adventure
#   genre_2                       : Science Fiction
#   genre_3                       : Action
# movieId                                                                                                               122914
# tmdbId                                                                                                                299534
# release_year                                                                                                            2019
# original_title                                                                                             Avengers: Endgame
# tagline                                                                                                   Avenge the fallen.
# overview                 After the devastating events of Avengers: Infinity War, the universe is in ruins due to the effo...
# produced_by_company_1                                                                                         Marvel Studios
# produced_by_company_2                                                                                                   None
# produced_in_country_1                                                                               United States of America
# produced_in_country_2                                                                                                   None
# spoken_language_1                                                                                                    English
# spoken_language_2                                                                                                   Japanese
# actor_1                                                                                                    Robert Downey Jr.
# actor_2                                                                                                          Chris Evans
# actor_3                                                                                                         Mark Ruffalo
# director_1                                                                                                     Anthony Russo
# writer_1                                                                                                     Stephen McFeely
# genre_1                                                                                                            Adventure
# genre_2                                                                                                      Science Fiction
# genre_3                                                                                                               Action
# Name: 58944, dtype: object

# %%
print("Done!")
# Out:
# Done!
